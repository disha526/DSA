# %% [markdown]
# <a href="https://colab.research.google.com/github/disha526/DSA/blob/main/DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## list and tuples

# %%
list = [1,2,3,4,5,6,7]
print(len(list))
print(list[-2])
print(list[0:7])
print(list[0:7:2])
print(list[::-1])
# Out:
# 7
# 6
# [1, 2, 3, 4, 5, 6, 7]
# [1, 3, 5, 7]
# [7, 6, 5, 4, 3, 2, 1]

# %%
list1 = [90,91,92,93]
list2 = [5,10,15,20,25]
list1.append([95,100])
print(list1)
list1.extend([0])
print(list1)
# Out:
# [90, 91, 92, 93, [95, 100]]
# [90, 91, 92, 93, [95, 100], 0]

# %%
print(list1.pop(-2))
# Out:
# [95, 100]

# %%
print(min(list2))
print(max(list2))
list3 =[23,34,45,67]
list3.insert(3,34)
print(list3)
# Out:
# 5
# 25
# [23, 34, 45, 34, 67]

# %%
list4 = [23,34,56]
list5 = list4
list5.append(67)
print(list4)
print(list5)
print(list4,id(list4))
print(list5,id(list5))
# Out:
# [23, 34, 56, 67]
# [23, 34, 56, 67]
# [23, 34, 56, 67] 135714934824448
# [23, 34, 56, 67] 135714934824448

# %%
list4 = [23,34,56]
list5 = list4.copy()
list4.append(67)
print(list4)
print(list5)
list5.clear()
list5
# Out:
# [23, 34, 56, 67]
# [23, 34, 56]
# []

# %%
tuple1 = (1,2,3,4)
tuple2 = tuple1
print(tuple1,id(tuple1))
print(tuple2,id(tuple2))
print(tuple1.count(2))
print(tuple1.index(4))
# Out:
# (1, 2, 3, 4) 135714548728832
# (1, 2, 3, 4) 135714548728832
# 1
# 3

# %% [markdown]
# ## Strings

# %%
s = "hello world"
print(s.replace("hello","hi"))
print(s.startswith("hello"))
print(s.startswith("hi"))
print(s.endswith("world"))
print(s.index("o"))
# Out:
# hi world
# True
# False
# True
# 4

# %%
name1= "dishakumble"
print(len(name1))
name2 = "diya"
print(name2)
name2 +="kumble"
print(name2)
print(name2.upper())
print(name1.lower())
print(name1.capitalize())
print(name2.replace("diya","disha"))
name1=name1.lower()
name1.count("i")
# Out:
# 11
# diya
# diyakumble
# DIYAKUMBLE
# dishakumble
# Dishakumble
# dishakumble
# 1

# %%
s = "      disha   kumble "
s = s.strip()
s
# Out:
# 'disha   kumble'

# %%
s1="-----dishakumble------"
s1.strip("-")
s2 = "hello my name is dishakumble"
print(__builtins__.list(s2))
print(s2.split(","))
s2 = "*".join(s2)
print(s2)
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'm', 'y', ' ', 'n', 'a', 'm', 'e', ' ', 'i', 's', ' ', 'd', 'i', 's', 'h', 'a', 'k', 'u', 'm', 'b', 'l', 'e']
# ['hello my name is dishakumble']
# h*e*l*l*o* *m*y* *n*a*m*e* *i*s* *d*i*s*h*a*k*u*m*b*l*e

# %%
s = "hello\ndisha"
print(s)
# Out:
# hello
# disha

# %%
print(ord('a'))
# Out:
# 97

# %% [markdown]
# ## Set

# %%
set1 = {2,4,"hello",2,"disha","hi",2,4}
print(set1) # no duplicates
print(len(set1))
# Out:
# {2, 4, 'hi', 'hello', 'disha'}
# 5

# %%
list6 = [3,4,5,6,7,7,7]
set2 = __builtins__.set(list6)
print(set2)
# Out:
# {3, 4, 5, 6, 7}

# %%
set2 = {2,4,"hello",2,"disha","hi",2,4}
set2.add(100)
set2.add("hello")
print(set2)
set2.discard("hello")
print(set2)
set2.remove(2)
# Out:
# {2, 4, 'hi', 'hello', 100, 'disha'}
# {2, 4, 'hi', 100, 'disha'}

# %%
#memebership
set3 = {2,4,"hello",2,"disha","hi",2,4}
if 4 in set3:
  print(True)
else:
  print(False)
set1.clear()
print(set1)
# Out:
# True
# set()

# %%
set4 = {1,2,3}
set4 = set1
set4.add(4)
print(set4)
# Out:
# {4}

# %%
set_a={1,8,5,2,4}
set_b ={4,5,6,8}
print(set_a |set_b)
print(set1.union(set2))
print(set_a & set_b)
print(set_a.intersection(set_b))
print(set_a - set_b)
print(set_a.difference(set_b))
# Out:
# {1, 2, 4, 5, 6, 8}
# {4, 'hi', 100, 'disha'}
# {8, 4, 5}
# {8, 4, 5}
# {1, 2}
# {1, 2}

# %% [markdown]
# ## Dictionary

# %%
dict1 = {1:"disha","hello":100, 10.21:"hi","key":True}
print(dict1)
print(type(dict1))
print(len(dict1))
# Out:
# {1: 'disha', 'hello': 100, 10.21: 'hi', 'key': True}
# <class 'dict'>
# 4

# %%
dict1 = {1:"disha","hello":100, 10.21:"hi","key":True}
print(dict[1])
print(dict1["hello"])
print(dict1)
# Out:
# dict[1]
# 100
# {1: 'disha', 'hello': 100, 10.21: 'hi', 'key': True}

# %%
dict1[5]="laxmi"
print(dict1)
dict1.update({10:"dinamani"})
# Out:
# {1: 'disha', 'hello': 100, 10.21: 'hi', 'key': True, 5: 'laxmi'}

# %%
dict1.pop(1)
# Out:
# 'disha'

# %%
dict2 = dict1
print(dict2)
# Out:
# {'hello': 100, 10.21: 'hi', 'key': True, 5: 'laxmi', 10: 'dinamani'}

# %%
dict1 = {1:"disha","hello":100, 10.21:"hi","key":True}
print(dict1.items())
for key,value in dict1.items():
  print(key,value)
# Out:
# dict_items([(1, 'disha'), ('hello', 100), (10.21, 'hi'), ('key', True)])
# 1 disha
# hello 100
# 10.21 hi
# key True

# %%
print(dict1.items())
for key in dict1.keys():
  print(key)
# Out:
# dict_items([(1, 'disha'), ('hello', 100), (10.21, 'hi'), ('key', True)])
# 1
# hello
# 10.21
# key

# %%
print(dict1.values())
for value in dict1.values():
  print(value)
# Out:
# dict_values(['disha', 100, 'hi', True])
# disha
# 100
# hi
# True

# %%
list1=["disha","diya","manu","madhav","shreya"]
freq ={}
for name in list1:
  if name not in freq:
    freq[name] = 1
  else:
    freq[name] += 1
print(freq)
# Out:
# {'disha': 1, 'diya': 1, 'manu': 1, 'madhav': 1, 'shreya': 1}

# %%
s = "disha loves skills"
freq ={}
for name in s:
  if name not in freq:
    freq[name] = 1
  else:
    freq[name] += 1
print(freq)
# Out:
# {'d': 1, 'i': 2, 's': 4, 'h': 1, 'a': 1, ' ': 2, 'l': 3, 'o': 1, 'v': 1, 'e': 1, 'k': 1}
